# %%
import pandas as pd

# %%
deg = pd.read_excel('./Analysis-Blebbistatin/deg_microarray.xlsx')

# %%
annotation_df = pd.read_csv('annotations.csv')

# %%
annotated_df = pd.merge(
    deg, annotation_df, on=['ID_REF']
    
)

# %%
annotated_df
# Out:
#              ID_REF     logFC    AveExpr          t   P.Value  adj.P.Val  \
# 0        1372256_at -1.556414   9.819773 -11.915076  0.000011   0.127998
# 1        1367627_at -1.403201   6.717285 -11.740256  0.000012   0.127998
# 2        1370012_at -1.752541  10.093318 -10.951285  0.000018   0.127998
# 3        1379629_at -1.832787   5.812755 -10.480873  0.000024   0.127998
# 4        1378716_at  1.616836   4.292733  10.415585  0.000025   0.127998
# ...             ...       ...        ...        ...       ...        ...
# 31089    1375715_at  0.000029   3.661857   0.000122  0.999906   0.999986
# 31090    1392557_at -0.000016   9.604613  -0.000031  0.999976   0.999986
# 31091    1381856_at  0.000008   3.786790   0.000030  0.999977   0.999986
# 31092  1376427_a_at -0.000002   3.395365  -0.000024  0.999981   0.999986
# 31093    1379061_at -0.000004   6.435799  -0.000018  0.999986   0.999986
#
#               B Gene Symbol                                   Gene Description
# ...

# %%
annotated_df.to_csv('annotated_deg.csv', sep=',', index=False)

# %%
annotated_df
# Out:
#              ID_REF     logFC    AveExpr          t   P.Value  adj.P.Val  \
# 0        1372256_at -1.556414   9.819773 -11.915076  0.000011   0.127998
# 1        1367627_at -1.403201   6.717285 -11.740256  0.000012   0.127998
# 2        1370012_at -1.752541  10.093318 -10.951285  0.000018   0.127998
# 3        1379629_at -1.832787   5.812755 -10.480873  0.000024   0.127998
# 4        1378716_at  1.616836   4.292733  10.415585  0.000025   0.127998
# ...             ...       ...        ...        ...       ...        ...
# 31089    1375715_at  0.000029   3.661857   0.000122  0.999906   0.999986
# 31090    1392557_at -0.000016   9.604613  -0.000031  0.999976   0.999986
# 31091    1381856_at  0.000008   3.786790   0.000030  0.999977   0.999986
# 31092  1376427_a_at -0.000002   3.395365  -0.000024  0.999981   0.999986
# 31093    1379061_at -0.000004   6.435799  -0.000018  0.999986   0.999986
#
#               B Gene Symbol                                   Gene Description
# ...

# %%
annotated_df = annotated_df[annotated_df['Gene Symbol'].notna()]

# %%
annotated_df.to_csv('annotated_deg_nona.csv', index=False)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(annotated_df['logFC'])
# Out:
# (array([3.0000e+00, 2.1000e+01, 1.9400e+02, 3.4230e+03, 1.4906e+04,
#         1.4100e+03, 7.7000e+01, 1.1000e+01, 2.0000e+00, 2.0000e+00]),
#  array([-2.97578684, -2.28071292, -1.585639  , -0.89056508, -0.19549115,
#          0.49958277,  1.19465669,  1.88973061,  2.58480454,  3.27987846,
#          3.97495238]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(annotated_df['logFC'], list(range(0, len(annotated_df['logFC']))) )

# %%
annotated_df
# Out:
#              ID_REF     logFC    AveExpr         t   P.Value  adj.P.Val  \
# 0        1395117_at  0.799256   3.817899  7.036216  0.000254   0.998047
# 1        1396237_at  1.074426   6.035887  6.329309  0.000474   0.998047
# 2        1373736_at  0.752313   6.733094  5.993520  0.000650   0.998047
# 3        1385032_at  0.985111   3.865518  5.846945  0.000750   0.998047
# 4        1377465_at  0.825656   4.138136  5.730314  0.000841   0.998047
# ...             ...       ...        ...       ...       ...        ...
# 31089    1395618_at  0.000034   9.611940  0.000279  0.999785   0.999896
# 31090    1391693_at -0.000089   7.277842 -0.000219  0.999832   0.999896
# 31091    1397047_at  0.000056   6.625308  0.000182  0.999860   0.999896
# 31092    1384637_at -0.000036   4.422112 -0.000143  0.999890   0.999896
# 31093  1386004_s_at -0.000015  12.047793 -0.000136  0.999896   0.999896
#
#               B Gene Symbol                                   Gene Description
# ...

# %%
annotated_df.drop_duplicates(subset=['ID_REF'], keep='first', inplace=False, ignore_index=False)
# Out:
#              ID_REF     logFC    AveExpr         t   P.Value  adj.P.Val  \
# 0        1395117_at  0.799256   3.817899  7.036216  0.000254   0.998047
# 1        1396237_at  1.074426   6.035887  6.329309  0.000474   0.998047
# 2        1373736_at  0.752313   6.733094  5.993520  0.000650   0.998047
# 3        1385032_at  0.985111   3.865518  5.846945  0.000750   0.998047
# 4        1377465_at  0.825656   4.138136  5.730314  0.000841   0.998047
# ...             ...       ...        ...       ...       ...        ...
# 31089    1395618_at  0.000034   9.611940  0.000279  0.999785   0.999896
# 31090    1391693_at -0.000089   7.277842 -0.000219  0.999832   0.999896
# 31091    1397047_at  0.000056   6.625308  0.000182  0.999860   0.999896
# 31092    1384637_at -0.000036   4.422112 -0.000143  0.999890   0.999896
# 31093  1386004_s_at -0.000015  12.047793 -0.000136  0.999896   0.999896
#
#               B Gene Symbol                                   Gene Description
# ...

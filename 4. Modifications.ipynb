# %%
import pandas as pd

# %%
data = pd.read_csv('./Analysis-Blebbistatin/annotated_deg_nona.csv')

# %%
data
# Out:
#              ID_REF     logFC    AveExpr          t   P.Value  adj.P.Val  \
# 0        1372256_at -1.556414   9.819773 -11.915076  0.000011   0.127998
# 1        1367627_at -1.403201   6.717285 -11.740256  0.000012   0.127998
# 2        1370012_at -1.752541  10.093318 -10.951285  0.000018   0.127998
# 3        1380287_at -1.614278   5.843482 -10.368012  0.000026   0.127998
# 4      1384036_s_at -1.944955   7.219002  -9.497625  0.000044   0.172433
# ...             ...       ...        ...        ...       ...        ...
# 20044    1390118_at  0.000024   8.169208   0.000214  0.999835   0.999986
# 20045    1373049_at -0.000066   8.818760  -0.000201  0.999846   0.999986
# 20046    1375715_at  0.000029   3.661857   0.000122  0.999906   0.999986
# 20047  1376427_a_at -0.000002   3.395365  -0.000024  0.999981   0.999986
# 20048    1379061_at -0.000004   6.435799  -0.000018  0.999986   0.999986
#
#               B Gene Symbol                                   Gene Description
# ...

# %%
df = data[data['Gene Symbol'].notna()]

# %%
df
# Out:
#              ID_REF     logFC    AveExpr          t   P.Value  adj.P.Val  \
# 0        1372256_at -1.556414   9.819773 -11.915076  0.000011   0.127998
# 1        1367627_at -1.403201   6.717285 -11.740256  0.000012   0.127998
# 2        1370012_at -1.752541  10.093318 -10.951285  0.000018   0.127998
# 3        1380287_at -1.614278   5.843482 -10.368012  0.000026   0.127998
# 4      1384036_s_at -1.944955   7.219002  -9.497625  0.000044   0.172433
# ...             ...       ...        ...        ...       ...        ...
# 20044    1390118_at  0.000024   8.169208   0.000214  0.999835   0.999986
# 20045    1373049_at -0.000066   8.818760  -0.000201  0.999846   0.999986
# 20046    1375715_at  0.000029   3.661857   0.000122  0.999906   0.999986
# 20047  1376427_a_at -0.000002   3.395365  -0.000024  0.999981   0.999986
# 20048    1379061_at -0.000004   6.435799  -0.000018  0.999986   0.999986
#
#               B Gene Symbol                                   Gene Description
# ...

# %%
# df.to_csv('annotated_deg.csv', index=False, sep=',')

# %%
# Find Upregulated and Downregulated

# %%
df_upregulated = df[(df['P.Value'] < 0.05) & (df['logFC'] > 1)].reset_index(drop=True)
df_upregulated_nopval = df[(df['logFC'] > 0.5)].reset_index(drop=True)

# %%
df_upregulated
# Out:
#          ID_REF     logFC    AveExpr         t   P.Value  adj.P.Val         B  \
# 0    1384262_at  1.216357   6.924790  8.431459  0.000092   0.217904  1.526259
# 1    1370237_at  1.105832  10.982059  8.383769  0.000095   0.217904  1.503068
# 2    1380021_at  1.249572   4.080050  7.716701  0.000157   0.230765  1.155785
# 3    1376972_at  1.104220   7.175447  7.548123  0.000180   0.230765  1.060819
# 4    1371439_at  1.000484   8.804113  7.271917  0.000224   0.230765  0.898436
# ..          ...       ...        ...       ...       ...        ...       ...
# 162  1390766_at  1.985678   7.549753  2.463348  0.045402   0.331827 -3.750833
# 163  1389812_at  1.059153   5.885472  2.451931  0.046145   0.333737 -3.765965
# 164  1388102_at  1.037972  11.306406  2.428725  0.047695   0.337106 -3.796734
# 165  1398250_at  1.756180   5.717417  2.415416  0.048608   0.338711 -3.814387
# 166  1377497_at  1.060919   6.957250  2.396907  0.049908   0.342041 -3.838941
#
# ...

# %%
df_upregulated_nopval
# Out:
#             ID_REF     logFC    AveExpr         t   P.Value  adj.P.Val  \
# 0       1384262_at  1.216357   6.924790  8.431459  0.000092   0.217904
# 1       1370237_at  1.105832  10.982059  8.383769  0.000095   0.217904
# 2     1393230_s_at  0.991162   8.152286  8.322419  0.000100   0.217904
# 3       1395117_at  0.987396   3.911968  8.250296  0.000105   0.217904
# 4       1380021_at  1.249572   4.080050  7.716701  0.000157   0.230765
# ...            ...       ...        ...       ...       ...        ...
# 1495    1370269_at  1.300869   8.223940  0.691007  0.513194   0.807397
# 1496    1384381_at  0.612796   6.167873  0.646007  0.540142   0.822055
# 1497    1372254_at  0.502944   9.487293  0.622674  0.554456   0.830620
# 1498    1370517_at  0.578188   9.973708  0.478134  0.648031   0.879051
# 1499    1384240_at  0.541367   7.009716  0.468602  0.654481   0.882656
#
#              B Gene Symbol                                   Gene Description
# ...

# %%
df_upregulated.to_csv('annotated_deg_pos_FC1.csv', index=False, sep=',')

# %%
df_downregulated = df[(df['P.Value'] < 0.05) & (df['logFC'] < -0.5)].reset_index(drop=True)
df_downregulated_nopval = df[(df['logFC'] < -0.5)].reset_index(drop=True)

# %%
df_downregulated
# Out:
#            ID_REF     logFC    AveExpr          t   P.Value  adj.P.Val  \
# 0      1372256_at -1.556414   9.819773 -11.915076  0.000011   0.127998
# 1      1367627_at -1.403201   6.717285 -11.740256  0.000012   0.127998
# 2      1370012_at -1.752541  10.093318 -10.951285  0.000018   0.127998
# 3      1380287_at -1.614278   5.843482 -10.368012  0.000026   0.127998
# 4    1384036_s_at -1.944955   7.219002  -9.497625  0.000044   0.172433
# ..            ...       ...        ...        ...       ...        ...
# 594    1368578_at -0.551721   4.490464  -2.412753  0.048793   0.339087
# 595    1372398_at -0.537436   8.543502  -2.412348  0.048821   0.339125
# 596    1373324_at -0.550361   7.842637  -2.405140  0.049326   0.341178
# 597  1370896_a_at -0.921765   8.255519  -2.403278  0.049457   0.341259
# 598    1378321_at -1.060483   8.277224  -2.398575  0.049790   0.341700
#
#             B Gene Symbol                                   Gene Description
# ...

# %%
df_downregulated_nopval
# Out:
#             ID_REF     logFC    AveExpr          t   P.Value  adj.P.Val  \
# 0       1372256_at -1.556414   9.819773 -11.915076  0.000011   0.127998
# 1       1367627_at -1.403201   6.717285 -11.740256  0.000012   0.127998
# 2       1370012_at -1.752541  10.093318 -10.951285  0.000018   0.127998
# 3       1380287_at -1.614278   5.843482 -10.368012  0.000026   0.127998
# 4     1384036_s_at -1.944955   7.219002  -9.497625  0.000044   0.172433
# ...            ...       ...        ...        ...       ...        ...
# 1004    1368742_at -0.669857   5.648392  -0.722659  0.494767   0.797161
# 1005    1374942_at -0.598249   4.918476  -0.709926  0.502126   0.801402
# 1006    1381572_at -0.502003   5.827383  -0.696264  0.510102   0.805899
# 1007    1371194_at -0.521972   5.553494  -0.576563  0.583411   0.845536
# 1008    1368078_at -0.589996   7.757543  -0.557121  0.595877   0.851735
#
#              B Gene Symbol                                   Gene Description
# ...

# %%
df_downregulated.to_csv('annotated_deg_neg_FC0.5.csv', index=False, sep=',')

# %%
df_downregulated_3 = df[(df['P.Value'] < 0.05) & (df['logFC'] < -0.3)].reset_index(drop=True)

# %%
df_downregulated_3
# Out:
#            ID_REF     logFC    AveExpr          t   P.Value  adj.P.Val  \
# 0      1372256_at -1.556414   9.819773 -11.915076  0.000011   0.127998
# 1      1367627_at -1.403201   6.717285 -11.740256  0.000012   0.127998
# 2      1370012_at -1.752541  10.093318 -10.951285  0.000018   0.127998
# 3      1380287_at -1.614278   5.843482 -10.368012  0.000026   0.127998
# 4    1384036_s_at -1.944955   7.219002  -9.497625  0.000044   0.172433
# ..            ...       ...        ...        ...       ...        ...
# 926    1369124_at -0.463809   6.276567  -2.400444  0.049657   0.341603
# 927    1367574_at -0.301491  13.159187  -2.400088  0.049682   0.341603
# 928    1367729_at -0.367426  10.975424  -2.398872  0.049769   0.341700
# 929    1378321_at -1.060483   8.277224  -2.398575  0.049790   0.341700
# 930    1381403_at -0.485576   7.170589  -2.397988  0.049831   0.341848
#
#             B Gene Symbol                                   Gene Description
# ...

# %%
df_downregulated_3.to_csv('annotated_deg_neg_3', index=False, sep=',')

# %%
df_downregulated_all = df[(df['P.Value'] < 0.05) & (df['logFC'] < 0)].reset_index(drop=True)

# %%
df_downregulated_all.to_csv('annotated_deg_neg_all.csv', index=False, sep=',')
